# %%
print("Hello World")
# Out:
# Hello World

# %%
import yaml 

yaml_file_path = "test.yaml"

## open yaml file and load the contents 
with open(yaml_file_path,"r") as yaml_file :
    data = yaml.safe_load(yaml_file)

# %%
print(data)
# Out:
# {'name': 'bappy', 'email': 'entbappy73@gmail.com'}

# %%
data["name"]
# Out:
# 'bappy'

# %% [markdown]
# # Configbox

# %%
from box import ConfigBox
d= ConfigBox(data)
d
# Out:
# ConfigBox({'name': 'bappy', 'email': 'entbappy73@gmail.com'})

# %%
d.name
# Out:
# 'bappy'
